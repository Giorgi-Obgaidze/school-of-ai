# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Basic setup

# %% [markdown]
# Create anaconda environment
# <br>
# ```bash
# conda create -n ml python=3.7.4 jupyter
# ```
# Install fastai library
# <br>
# ```bash
# conda install -c pytorch -c fastai fastai
# ```

# %%
# !pip install https://github.com/ipython-contrib/jupyter_contrib_nbextensions/tarball/master
# !pip install jupyter_nbextensions_configurator
# !jupyter contrib nbextension install --user
# !jupyter nbextensions_configurator enable --user
# Out:
# Collecting https://github.com/ipython-contrib/jupyter_contrib_nbextensions/tarball/master
#   Downloading https://github.com/ipython-contrib/jupyter_contrib_nbextensions/tarball/master
#      - 29.3MB 455kB/s    / 7.9MB 1.1MB/s
# Requirement already satisfied (use --upgrade to upgrade): jupyter-contrib-nbextensions==0.5.1 from https://github.com/ipython-contrib/jupyter_contrib_nbextensions/tarball/master in /home/obga/anaconda3/lib/python3.7/site-packages
# Requirement already satisfied: ipython_genutils in /home/obga/anaconda3/lib/python3.7/site-packages (from jupyter-contrib-nbextensions==0.5.1) (0.2.0)
# Requirement already satisfied: jupyter_contrib_core>=0.3.3 in /home/obga/anaconda3/lib/python3.7/site-packages (from jupyter-contrib-nbextensions==0.5.1) (0.3.3)
# Requirement already satisfied: jupyter_core in /home/obga/anaconda3/lib/python3.7/site-packages (from jupyter-contrib-nbextensions==0.5.1) (4.5.0)
# Requirement already satisfied: jupyter_highlight_selected_word>=0.1.1 in /home/obga/anaconda3/lib/python3.7/site-packages (from jupyter-contrib-nbextensions==0.5.1) (0.2.0)
# Requirement already satisfied: jupyter_latex_envs>=1.3.8 in /home/obga/anaconda3/lib/python3.7/site-packages (from jupyter-contrib-nbextensions==0.5.1) (1.4.6)
# Requirement already satisfied: jupyter_nbextensions_configurator>=0.4.0 in /home/obga/anaconda3/lib/python3.7/site-packages (from jupyter-contrib-nbextensions==0.5.1) (0.4.1)
# Requirement already satisfied: nbconvert>=4.2 in /home/obga/anaconda3/lib/python3.7/site-packages (from jupyter-contrib-nbextensions==0.5.1) (5.5.0)
# Requirement already satisfied: notebook>=4.0 in /home/obga/anaconda3/lib/python3.7/site-packages (from jupyter-contrib-nbextensions==0.5.1) (6.0.0)
# Requirement already satisfied: pyyaml in /home/obga/anaconda3/lib/python3.7/site-packages (from jupyter-contrib-nbextensions==0.5.1) (5.1.1)
# Requirement already satisfied: tornado in /home/obga/anaconda3/lib/python3.7/site-packages (from jupyter-contrib-nbextensions==0.5.1) (6.0.3)
# Requirement already satisfied: traitlets>=4.1 in /home/obga/anaconda3/lib/python3.7/site-packages (from jupyter-contrib-nbextensions==0.5.1) (4.3.2)
# Requirement already satisfied: lxml in /home/obga/anaconda3/lib/python3.7/site-packages (from jupyter-contrib-nbextensions==0.5.1) (4.3.4)
# Requirement already satisfied: setuptools in /home/obga/anaconda3/lib/python3.7/site-packages (from jupyter_contrib_core>=0.3.3->jupyter-contrib-nbextensions==0.5.1) (41.0.1)
# Requirement already satisfied: ipython in /home/obga/anaconda3/lib/python3.7/site-packages (from jupyter_latex_envs>=1.3.8->jupyter-contrib-nbextensions==0.5.1) (7.6.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /home/obga/anaconda3/lib/python3.7/site-packages (from nbconvert>=4.2->jupyter-contrib-nbextensions==0.5.1) (0.3)
# Requirement already satisfied: jinja2>=2.4 in /home/obga/anaconda3/lib/python3.7/site-packages (from nbconvert>=4.2->jupyter-contrib-nbextensions==0.5.1) (2.10.1)
# Requirement already satisfied: defusedxml in /home/obga/anaconda3/lib/python3.7/site-packages (from nbconvert>=4.2->jupyter-contrib-nbextensions==0.5.1) (0.6.0)
# Requirement already satisfied: testpath in /home/obga/anaconda3/lib/python3.7/site-packages (from nbconvert>=4.2->jupyter-contrib-nbextensions==0.5.1) (0.4.2)
# Requirement already satisfied: mistune>=0.8.1 in /home/obga/anaconda3/lib/python3.7/site-packages (from nbconvert>=4.2->jupyter-contrib-nbextensions==0.5.1) (0.8.4)
# Requirement already satisfied: bleach in /home/obga/anaconda3/lib/python3.7/site-packages (from nbconvert>=4.2->jupyter-contrib-nbextensions==0.5.1) (3.1.0)
# Requirement already satisfied: pygments in /home/obga/anaconda3/lib/python3.7/site-packages (from nbconvert>=4.2->jupyter-contrib-nbextensions==0.5.1) (2.4.2)
# Requirement already satisfied: nbformat>=4.4 in /home/obga/anaconda3/lib/python3.7/site-packages (from nbconvert>=4.2->jupyter-contrib-nbextensions==0.5.1) (4.4.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/obga/anaconda3/lib/python3.7/site-packages (from nbconvert>=4.2->jupyter-contrib-nbextensions==0.5.1) (1.4.2)
# Requirement already satisfied: prometheus-client in /home/obga/anaconda3/lib/python3.7/site-packages (from notebook>=4.0->jupyter-contrib-nbextensions==0.5.1) (0.7.1)
# Requirement already satisfied: jupyter-client>=5.3.1 in /home/obga/anaconda3/lib/python3.7/site-packages (from notebook>=4.0->jupyter-contrib-nbextensions==0.5.1) (5.3.1)
# Requirement already satisfied: ipykernel in /home/obga/anaconda3/lib/python3.7/site-packages (from notebook>=4.0->jupyter-contrib-nbextensions==0.5.1) (5.1.1)
# Requirement already satisfied: terminado>=0.8.1 in /home/obga/anaconda3/lib/python3.7/site-packages (from notebook>=4.0->jupyter-contrib-nbextensions==0.5.1) (0.8.2)
# Requirement already satisfied: Send2Trash in /home/obga/anaconda3/lib/python3.7/site-packages (from notebook>=4.0->jupyter-contrib-nbextensions==0.5.1) (1.5.0)
# Requirement already satisfied: pyzmq>=17 in /home/obga/anaconda3/lib/python3.7/site-packages (from notebook>=4.0->jupyter-contrib-nbextensions==0.5.1) (18.0.0)
# Requirement already satisfied: six in /home/obga/anaconda3/lib/python3.7/site-packages (from traitlets>=4.1->jupyter-contrib-nbextensions==0.5.1) (1.12.0)
# Requirement already satisfied: decorator in /home/obga/anaconda3/lib/python3.7/site-packages (from traitlets>=4.1->jupyter-contrib-nbextensions==0.5.1) (4.4.0)
# Requirement already satisfied: pickleshare in /home/obga/anaconda3/lib/python3.7/site-packages (from ipython->jupyter_latex_envs>=1.3.8->jupyter-contrib-nbextensions==0.5.1) (0.7.5)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /home/obga/anaconda3/lib/python3.7/site-packages (from ipython->jupyter_latex_envs>=1.3.8->jupyter-contrib-nbextensions==0.5.1) (4.7.0)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /home/obga/anaconda3/lib/python3.7/site-packages (from ipython->jupyter_latex_envs>=1.3.8->jupyter-contrib-nbextensions==0.5.1) (2.0.9)
# Requirement already satisfied: jedi>=0.10 in /home/obga/anaconda3/lib/python3.7/site-packages (from ipython->jupyter_latex_envs>=1.3.8->jupyter-contrib-nbextensions==0.5.1) (0.13.3)
# Requirement already satisfied: backcall in /home/obga/anaconda3/lib/python3.7/site-packages (from ipython->jupyter_latex_envs>=1.3.8->jupyter-contrib-nbextensions==0.5.1) (0.1.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/obga/anaconda3/lib/python3.7/site-packages (from jinja2>=2.4->nbconvert>=4.2->jupyter-contrib-nbextensions==0.5.1) (1.1.1)
# Requirement already satisfied: webencodings in /home/obga/anaconda3/lib/python3.7/site-packages (from bleach->nbconvert>=4.2->jupyter-contrib-nbextensions==0.5.1) (0.5.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /home/obga/anaconda3/lib/python3.7/site-packages (from nbformat>=4.4->nbconvert>=4.2->jupyter-contrib-nbextensions==0.5.1) (3.0.1)
# Requirement already satisfied: python-dateutil>=2.1 in /home/obga/anaconda3/lib/python3.7/site-packages (from jupyter-client>=5.3.1->notebook>=4.0->jupyter-contrib-nbextensions==0.5.1) (2.8.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/obga/anaconda3/lib/python3.7/site-packages (from pexpect; sys_platform != "win32"->ipython->jupyter_latex_envs>=1.3.8->jupyter-contrib-nbextensions==0.5.1) (0.6.0)
# Requirement already satisfied: wcwidth in /home/obga/anaconda3/lib/python3.7/site-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython->jupyter_latex_envs>=1.3.8->jupyter-contrib-nbextensions==0.5.1) (0.1.7)
# Requirement already satisfied: parso>=0.3.0 in /home/obga/anaconda3/lib/python3.7/site-packages (from jedi>=0.10->ipython->jupyter_latex_envs>=1.3.8->jupyter-contrib-nbextensions==0.5.1) (0.5.0)
# Requirement already satisfied: attrs>=17.4.0 in /home/obga/anaconda3/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert>=4.2->jupyter-contrib-nbextensions==0.5.1) (19.1.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /home/obga/anaconda3/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert>=4.2->jupyter-contrib-nbextensions==0.5.1) (0.14.11)
# Building wheels for collected packages: jupyter-contrib-nbextensions
#   Building wheel for jupyter-contrib-nbextensions (setup.py) ... done
#   Stored in directory: /tmp/pip-ephem-wheel-cache-plxh988c/wheels/22/4a/9f/df59e985684a10ea0e025300581870b5b3a300ee3525f0eef5
# Successfully built jupyter-contrib-nbextensions
# Requirement already satisfied: jupyter_nbextensions_configurator in /home/obga/anaconda3/lib/python3.7/site-packages (0.4.1)
# Requirement already satisfied: tornado in /home/obga/anaconda3/lib/python3.7/site-packages (from jupyter_nbextensions_configurator) (6.0.3)
# Requirement already satisfied: traitlets in /home/obga/anaconda3/lib/python3.7/site-packages (from jupyter_nbextensions_configurator) (4.3.2)
# Requirement already satisfied: jupyter-contrib-core>=0.3.3 in /home/obga/anaconda3/lib/python3.7/site-packages (from jupyter_nbextensions_configurator) (0.3.3)
# Requirement already satisfied: jupyter-core in /home/obga/anaconda3/lib/python3.7/site-packages (from jupyter_nbextensions_configurator) (4.5.0)
# Requirement already satisfied: pyyaml in /home/obga/anaconda3/lib/python3.7/site-packages (from jupyter_nbextensions_configurator) (5.1.1)
# Requirement already satisfied: notebook>=4.0 in /home/obga/anaconda3/lib/python3.7/site-packages (from jupyter_nbextensions_configurator) (6.0.0)
# Requirement already satisfied: ipython-genutils in /home/obga/anaconda3/lib/python3.7/site-packages (from traitlets->jupyter_nbextensions_configurator) (0.2.0)
# Requirement already satisfied: decorator in /home/obga/anaconda3/lib/python3.7/site-packages (from traitlets->jupyter_nbextensions_configurator) (4.4.0)
# Requirement already satisfied: six in /home/obga/anaconda3/lib/python3.7/site-packages (from traitlets->jupyter_nbextensions_configurator) (1.12.0)
# Requirement already satisfied: setuptools in /home/obga/anaconda3/lib/python3.7/site-packages (from jupyter-contrib-core>=0.3.3->jupyter_nbextensions_configurator) (41.0.1)
# Requirement already satisfied: terminado>=0.8.1 in /home/obga/anaconda3/lib/python3.7/site-packages (from notebook>=4.0->jupyter_nbextensions_configurator) (0.8.2)
# Requirement already satisfied: jinja2 in /home/obga/anaconda3/lib/python3.7/site-packages (from notebook>=4.0->jupyter_nbextensions_configurator) (2.10.1)
# Requirement already satisfied: prometheus-client in /home/obga/anaconda3/lib/python3.7/site-packages (from notebook>=4.0->jupyter_nbextensions_configurator) (0.7.1)
# Requirement already satisfied: pyzmq>=17 in /home/obga/anaconda3/lib/python3.7/site-packages (from notebook>=4.0->jupyter_nbextensions_configurator) (18.0.0)
# Requirement already satisfied: nbformat in /home/obga/anaconda3/lib/python3.7/site-packages (from notebook>=4.0->jupyter_nbextensions_configurator) (4.4.0)
# Requirement already satisfied: nbconvert in /home/obga/anaconda3/lib/python3.7/site-packages (from notebook>=4.0->jupyter_nbextensions_configurator) (5.5.0)
# Requirement already satisfied: Send2Trash in /home/obga/anaconda3/lib/python3.7/site-packages (from notebook>=4.0->jupyter_nbextensions_configurator) (1.5.0)
# Requirement already satisfied: ipykernel in /home/obga/anaconda3/lib/python3.7/site-packages (from notebook>=4.0->jupyter_nbextensions_configurator) (5.1.1)
# Requirement already satisfied: jupyter-client>=5.3.1 in /home/obga/anaconda3/lib/python3.7/site-packages (from notebook>=4.0->jupyter_nbextensions_configurator) (5.3.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/obga/anaconda3/lib/python3.7/site-packages (from jinja2->notebook>=4.0->jupyter_nbextensions_configurator) (1.1.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /home/obga/anaconda3/lib/python3.7/site-packages (from nbformat->notebook>=4.0->jupyter_nbextensions_configurator) (3.0.1)
# Requirement already satisfied: pygments in /home/obga/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.0->jupyter_nbextensions_configurator) (2.4.2)
# Requirement already satisfied: entrypoints>=0.2.2 in /home/obga/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.0->jupyter_nbextensions_configurator) (0.3)
# Requirement already satisfied: testpath in /home/obga/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.0->jupyter_nbextensions_configurator) (0.4.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/obga/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.0->jupyter_nbextensions_configurator) (1.4.2)
# Requirement already satisfied: defusedxml in /home/obga/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.0->jupyter_nbextensions_configurator) (0.6.0)
# Requirement already satisfied: bleach in /home/obga/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.0->jupyter_nbextensions_configurator) (3.1.0)
# Requirement already satisfied: mistune>=0.8.1 in /home/obga/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.0->jupyter_nbextensions_configurator) (0.8.4)
# Requirement already satisfied: ipython>=5.0.0 in /home/obga/anaconda3/lib/python3.7/site-packages (from ipykernel->notebook>=4.0->jupyter_nbextensions_configurator) (7.6.1)
# Requirement already satisfied: python-dateutil>=2.1 in /home/obga/anaconda3/lib/python3.7/site-packages (from jupyter-client>=5.3.1->notebook>=4.0->jupyter_nbextensions_configurator) (2.8.0)
# Requirement already satisfied: attrs>=17.4.0 in /home/obga/anaconda3/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook>=4.0->jupyter_nbextensions_configurator) (19.1.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /home/obga/anaconda3/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook>=4.0->jupyter_nbextensions_configurator) (0.14.11)
# Requirement already satisfied: webencodings in /home/obga/anaconda3/lib/python3.7/site-packages (from bleach->nbconvert->notebook>=4.0->jupyter_nbextensions_configurator) (0.5.1)
# Requirement already satisfied: jedi>=0.10 in /home/obga/anaconda3/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel->notebook>=4.0->jupyter_nbextensions_configurator) (0.13.3)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /home/obga/anaconda3/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel->notebook>=4.0->jupyter_nbextensions_configurator) (4.7.0)
# Requirement already satisfied: backcall in /home/obga/anaconda3/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel->notebook>=4.0->jupyter_nbextensions_configurator) (0.1.0)
# Requirement already satisfied: pickleshare in /home/obga/anaconda3/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel->notebook>=4.0->jupyter_nbextensions_configurator) (0.7.5)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /home/obga/anaconda3/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel->notebook>=4.0->jupyter_nbextensions_configurator) (2.0.9)
# Requirement already satisfied: parso>=0.3.0 in /home/obga/anaconda3/lib/python3.7/site-packages (from jedi>=0.10->ipython>=5.0.0->ipykernel->notebook>=4.0->jupyter_nbextensions_configurator) (0.5.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/obga/anaconda3/lib/python3.7/site-packages (from pexpect; sys_platform != "win32"->ipython>=5.0.0->ipykernel->notebook>=4.0->jupyter_nbextensions_configurator) (0.6.0)
# Requirement already satisfied: wcwidth in /home/obga/anaconda3/lib/python3.7/site-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=5.0.0->ipykernel->notebook>=4.0->jupyter_nbextensions_configurator) (0.1.7)
# [I 16:02:30 InstallContribNbextensionsApp] jupyter contrib nbextension install --user
# [I 16:02:30 InstallContribNbextensionsApp] Installing jupyter_contrib_nbextensions nbextension files to jupyter data directory
# [I 16:02:30 InstallContribNbextensionsApp] Installing /home/obga/anaconda3/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/toc2 -> toc2
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/toc2/toc2.yaml
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/toc2/image.png
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/toc2/demo2.gif
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/toc2/main.js
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/toc2/README.md
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/toc2/demo3.gif
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/toc2/icon.png
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/toc2/toc2.js
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/toc2/main.css
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/toc2/demo.gif
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/toc2/demo_dark.png
# [I 16:02:30 InstallContribNbextensionsApp] - Validating: OK
# [I 16:02:30 InstallContribNbextensionsApp] Installing /home/obga/anaconda3/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/go_to_current_running_cell -> go_to_current_running_cell
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/go_to_current_running_cell/go_to_current_running_cell.yaml
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/go_to_current_running_cell/main.js
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/go_to_current_running_cell/anchor.png
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/go_to_current_running_cell/README.md
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/go_to_current_running_cell/jump_to_cell.gif
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/go_to_current_running_cell/auto_focus.gif
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/go_to_current_running_cell/eye.png
# [I 16:02:30 InstallContribNbextensionsApp] - Validating: OK
# [I 16:02:30 InstallContribNbextensionsApp] Installing /home/obga/anaconda3/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/gist_it -> gist_it
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/gist_it/readme.md
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/gist_it/main.js
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/gist_it/gist_it.yaml
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/gist_it/icon.png
# [I 16:02:30 InstallContribNbextensionsApp] - Validating: OK
# [I 16:02:30 InstallContribNbextensionsApp] Installing /home/obga/anaconda3/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/snippets -> snippets
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/snippets/snippets.yaml
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/snippets/snippets.json
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/snippets/main.js
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/snippets/README.md
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/snippets/snippets-demo.gif
# [I 16:02:30 InstallContribNbextensionsApp] - Validating: OK
# [I 16:02:30 InstallContribNbextensionsApp] Installing /home/obga/anaconda3/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/scroll_down -> scroll_down
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/scroll_down/readme.md
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/scroll_down/config.yaml
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/scroll_down/main.js
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/scroll_down/icon.png
# [I 16:02:30 InstallContribNbextensionsApp] - Validating: OK
# [I 16:02:30 InstallContribNbextensionsApp] Installing /home/obga/anaconda3/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/freeze -> freeze
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/freeze/readme.md
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/freeze/config.yaml
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/freeze/main.js
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/freeze/icon.png
# [I 16:02:30 InstallContribNbextensionsApp] - Validating: OK
# [I 16:02:30 InstallContribNbextensionsApp] Installing /home/obga/anaconda3/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/execute_time -> execute_time
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/execute_time/ExecuteTime.css
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/execute_time/execution-timings-menu.png
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/execute_time/execution-timings-box.png
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/execute_time/ExecuteTime.js
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/execute_time/readme.md
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/execute_time/ExecuteTime.yaml
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/execute_time/icon.png
# [I 16:02:30 InstallContribNbextensionsApp] - Validating: OK
# [I 16:02:30 InstallContribNbextensionsApp] Installing /home/obga/anaconda3/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/toggle_all_line_numbers -> toggle_all_line_numbers
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/toggle_all_line_numbers/readme.md
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/toggle_all_line_numbers/main.js
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/toggle_all_line_numbers/main.yaml
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/toggle_all_line_numbers/icon.png
# [I 16:02:30 InstallContribNbextensionsApp] - Validating: OK
# [I 16:02:30 InstallContribNbextensionsApp] Installing /home/obga/anaconda3/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/navigation-hotkeys -> navigation-hotkeys
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/navigation-hotkeys/readme.md
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/navigation-hotkeys/main.js
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/navigation-hotkeys/icon.png
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/navigation-hotkeys/hotkeys.yaml
# [I 16:02:30 InstallContribNbextensionsApp] - Validating: OK
# [I 16:02:30 InstallContribNbextensionsApp] Installing /home/obga/anaconda3/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/tree-filter -> tree-filter
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/tree-filter/readme.md
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/tree-filter/tree-filter.yaml
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/tree-filter/index.js
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/tree-filter/demo.gif
# [I 16:02:30 InstallContribNbextensionsApp] - Validating: OK
# [I 16:02:30 InstallContribNbextensionsApp] Installing /home/obga/anaconda3/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/autosavetime -> autosavetime
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/autosavetime/main.js
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/autosavetime/README.md
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/autosavetime/autosavetime.yaml
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/autosavetime/icon.png
# [I 16:02:30 InstallContribNbextensionsApp] - Validating: OK
# [I 16:02:30 InstallContribNbextensionsApp] Installing /home/obga/anaconda3/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/spellchecker -> spellchecker
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/spellchecker/config.yaml
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/spellchecker/main.js
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/spellchecker/screenshot.png
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/spellchecker/download_new_dict.py
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/spellchecker/README.md
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/spellchecker/main.css
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/spellchecker/__pycache__/download_new_dict.cpython-37.pyc
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/spellchecker/typo/LICENSE.txt
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/spellchecker/typo/typo.js
# [I 16:02:30 InstallContribNbextensionsApp] - Validating: OK
# [I 16:02:30 InstallContribNbextensionsApp] Installing /home/obga/anaconda3/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/addbefore -> addbefore
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/addbefore/readme.md
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/addbefore/main.js
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/addbefore/icon.png
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/addbefore/addbefore.yaml
# [I 16:02:30 InstallContribNbextensionsApp] - Validating: OK
# [I 16:02:30 InstallContribNbextensionsApp] Installing /home/obga/anaconda3/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/autoscroll -> autoscroll
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/autoscroll/autoscroll.yaml
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/autoscroll/main.js
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/autoscroll/README.md
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/autoscroll/icon.png
# [I 16:02:30 InstallContribNbextensionsApp] - Validating: OK
# [I 16:02:30 InstallContribNbextensionsApp] Installing /home/obga/anaconda3/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/cell_filter -> cell_filter
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/cell_filter/cell_filter.yml
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/cell_filter/README.md
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/cell_filter/cell_filter.js
# [I 16:02:30 InstallContribNbextensionsApp] - Validating: OK
# [I 16:02:30 InstallContribNbextensionsApp] Installing /home/obga/anaconda3/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/help_panel -> help_panel
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/help_panel/help_panel_ext_fullscreen.png
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/help_panel/readme.md
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/help_panel/help_panel.css
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/help_panel/icon.png
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/help_panel/help_panel.yaml
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/help_panel/help_panel.js
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/help_panel/help_panel_ext.png
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/help_panel/img/handle-v.png
# [I 16:02:30 InstallContribNbextensionsApp] - Validating: OK
# [I 16:02:30 InstallContribNbextensionsApp] Installing /home/obga/anaconda3/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/comment-uncomment -> comment-uncomment
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/comment-uncomment/readme.md
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/comment-uncomment/main.js
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/comment-uncomment/icon.png
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/comment-uncomment/comment-uncomment.yaml
# [I 16:02:30 InstallContribNbextensionsApp] - Validating: OK
# [I 16:02:30 InstallContribNbextensionsApp] Installing /home/obga/anaconda3/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/python-markdown -> python-markdown
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/python-markdown/python-markdown.png
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/python-markdown/readme.md
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/python-markdown/main.js
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/python-markdown/untrusted.png
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/python-markdown/python-markdown.yaml
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/python-markdown/trusted.png
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/python-markdown/main.css
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/python-markdown/python-markdown-pre.png
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/python-markdown/python-markdown-post.png
# [I 16:02:30 InstallContribNbextensionsApp] - Validating: OK
# [I 16:02:30 InstallContribNbextensionsApp] Installing /home/obga/anaconda3/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/code_prettify -> code_prettify
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/README_isort.md
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/kernel_exec_on_cell.js
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/autopep8.yaml
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/code_prettify.yaml
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/isort.js
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/README.md
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/demo-R.gif
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/demo-jv.gif
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/2to3.yaml
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/isort.yaml
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/2to3.js
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/demo_2to3.gif
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/README_2to3.md
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/demo-py.gif
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/README_code_prettify.md
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/code_prettify.js
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/README_autopep8.md
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/autopep8.js
# [I 16:02:30 InstallContribNbextensionsApp] - Validating: OK
# [I 16:02:30 InstallContribNbextensionsApp] Installing /home/obga/anaconda3/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/code_prettify -> code_prettify
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/README_isort.md
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/kernel_exec_on_cell.js
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/autopep8.yaml
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/code_prettify.yaml
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/isort.js
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/README.md
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/demo-R.gif
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/demo-jv.gif
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/2to3.yaml
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/isort.yaml
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/2to3.js
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/demo_2to3.gif
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/README_2to3.md
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/demo-py.gif
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/README_code_prettify.md
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/code_prettify.js
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/README_autopep8.md
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/autopep8.js
# [I 16:02:30 InstallContribNbextensionsApp] - Validating: OK
# [I 16:02:30 InstallContribNbextensionsApp] Installing /home/obga/anaconda3/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/code_prettify -> code_prettify
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/README_isort.md
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/kernel_exec_on_cell.js
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/autopep8.yaml
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/code_prettify.yaml
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/isort.js
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/README.md
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/demo-R.gif
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/demo-jv.gif
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/2to3.yaml
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/isort.yaml
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/2to3.js
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/demo_2to3.gif
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/README_2to3.md
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/demo-py.gif
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/README_code_prettify.md
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/code_prettify.js
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/README_autopep8.md
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/autopep8.js
# [I 16:02:30 InstallContribNbextensionsApp] - Validating: OK
# [I 16:02:30 InstallContribNbextensionsApp] Installing /home/obga/anaconda3/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/code_prettify -> code_prettify
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/README_isort.md
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/kernel_exec_on_cell.js
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/autopep8.yaml
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/code_prettify.yaml
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/isort.js
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/README.md
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/demo-R.gif
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/demo-jv.gif
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/2to3.yaml
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/isort.yaml
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/2to3.js
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/demo_2to3.gif
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/README_2to3.md
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/demo-py.gif
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/README_code_prettify.md
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/code_prettify.js
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/README_autopep8.md
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_prettify/autopep8.js
# [I 16:02:30 InstallContribNbextensionsApp] - Validating: OK
# [I 16:02:30 InstallContribNbextensionsApp] Installing /home/obga/anaconda3/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/select_keymap -> select_keymap
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/select_keymap/select_keymap.png
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/select_keymap/main.js
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/select_keymap/select_keymap.yaml
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/select_keymap/README.md
# [I 16:02:30 InstallContribNbextensionsApp] - Validating: OK
# [I 16:02:30 InstallContribNbextensionsApp] Installing /home/obga/anaconda3/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/skill -> skill
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/skill/main.js
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/skill/README.md
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/skill/skill.js
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/skill/skill.yaml
# [I 16:02:30 InstallContribNbextensionsApp] - Validating: OK
# [I 16:02:30 InstallContribNbextensionsApp] Installing /home/obga/anaconda3/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/highlighter -> highlighter
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/highlighter/tst_highlights.pdf
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/highlighter/readme.md
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/highlighter/tst_highlights.html
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/highlighter/export_highlights.pdf
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/highlighter/export_highlights.html
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/highlighter/highlighter.yaml
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/highlighter/demo_highlighter.ipynb
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/highlighter/image.gif
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/highlighter/export_highlights.tex
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/highlighter/highlighter.js
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/highlighter/icon.png
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/highlighter/tst_highlights.ipynb
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/highlighter/tst_highlights.tex
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/highlighter/demo_highlighter.html
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/highlighter/export_highlights.ipynb
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/highlighter/highlighter.css
# [I 16:02:30 InstallContribNbextensionsApp] - Validating: OK
# [I 16:02:30 InstallContribNbextensionsApp] Installing /home/obga/anaconda3/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/collapsible_headings -> collapsible_headings
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/collapsible_headings/readme.md
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/collapsible_headings/main.js
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/collapsible_headings/screenshot.png
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/collapsible_headings/icon.png
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/collapsible_headings/collapsible_headings.yaml
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/collapsible_headings/main.css
# [I 16:02:30 InstallContribNbextensionsApp] - Validating: OK
# [I 16:02:30 InstallContribNbextensionsApp] Installing /home/obga/anaconda3/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/datestamper -> datestamper
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/datestamper/readme.md
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/datestamper/main.js
# ...
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_font_size/code_font_size.js
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_font_size/README.md
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/code_font_size/code_font_size.yaml
# [I 16:02:30 InstallContribNbextensionsApp] - Validating: OK
# [I 16:02:30 InstallContribNbextensionsApp] Installing /home/obga/anaconda3/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/ruler -> ruler
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/ruler/readme.md
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/ruler/ruler_editor.yaml
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/ruler/main.js
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/ruler/ruler.yaml
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/ruler/edit.js
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/ruler/icon.png
# [I 16:02:30 InstallContribNbextensionsApp] - Validating: OK
# [I 16:02:30 InstallContribNbextensionsApp] Installing /home/obga/anaconda3/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/ruler -> ruler
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/ruler/readme.md
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/ruler/ruler_editor.yaml
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/ruler/main.js
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/ruler/ruler.yaml
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/ruler/edit.js
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/ruler/icon.png
# [I 16:02:30 InstallContribNbextensionsApp] - Validating: OK
# [I 16:02:30 InstallContribNbextensionsApp] Installing /home/obga/anaconda3/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/equation-numbering -> equation-numbering
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/equation-numbering/readme.md
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/equation-numbering/main.js
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/equation-numbering/button.png
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/equation-numbering/info.yaml
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/equation-numbering/icon.png
# [I 16:02:30 InstallContribNbextensionsApp] - Validating: OK
# [I 16:02:30 InstallContribNbextensionsApp] Installing /home/obga/anaconda3/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/exercise -> exercise
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/exercise/readme.md
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/exercise/main.js
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/exercise/exercise.yaml
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/exercise/image.gif
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/exercise/icon.png
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/exercise/main.css
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/exercise/history.md
# [I 16:02:30 InstallContribNbextensionsApp] - Validating: OK
# [I 16:02:30 InstallContribNbextensionsApp] Installing /home/obga/anaconda3/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/scratchpad -> scratchpad
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/scratchpad/main.js
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/scratchpad/README.md
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/scratchpad/scratchpad.yaml
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/scratchpad/demo.gif
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/scratchpad/LICENSE
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/scratchpad/scratchpad.css
# [I 16:02:30 InstallContribNbextensionsApp] - Validating: OK
# [I 16:02:30 InstallContribNbextensionsApp] Installing /home/obga/anaconda3/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/nbTranslate -> nbTranslate
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/nbTranslate/demo2.gif
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/nbTranslate/main.js
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/nbTranslate/README.md
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/nbTranslate/mutils.js
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/nbTranslate/demo1.gif
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/nbTranslate/nbTranslate.yaml
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/nbTranslate/nbTranslate.js
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/nbTranslate/languages.js
# [I 16:02:30 InstallContribNbextensionsApp] - Validating: OK
# [I 16:02:30 InstallContribNbextensionsApp] Installing /home/obga/anaconda3/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/hide_input -> hide_input
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/hide_input/readme.md
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/hide_input/main.js
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/hide_input/icon.png
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/hide_input/hide-input.yaml
# [I 16:02:30 InstallContribNbextensionsApp] - Validating: OK
# [I 16:02:30 InstallContribNbextensionsApp] Installing /home/obga/anaconda3/lib/python3.7/site-packages/jupyter_highlight_selected_word/static/highlight_selected_word -> highlight_selected_word
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/highlight_selected_word/configurator.yaml
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/highlight_selected_word/main.js
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/highlight_selected_word/README.md
# [I 16:02:30 InstallContribNbextensionsApp] - Validating: OK
# [I 16:02:30 InstallContribNbextensionsApp] Installing /home/obga/anaconda3/lib/python3.7/site-packages/latex_envs/static -> latex_envs
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/latex_envs/latex_envs.js
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/latex_envs/latex_envs.yaml
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/latex_envs/latex_envs.css
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/latex_envs/initNb.js
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/latex_envs/thmsInNb4.js
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/latex_envs/README.md
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/latex_envs/configuration_toolbar.png
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/latex_envs/envsLatex.js
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/latex_envs/envsLatex.json
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/latex_envs/main_toolbar.png
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/latex_envs/icon.png
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/latex_envs/example_user_envs.json
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/latex_envs/example.png
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/latex_envs/bibInNb4.js
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/latex_envs/bibtex2.js
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/latex_envs/doc/Toggles.png
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/latex_envs/doc/documentation.tex
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/latex_envs/doc/config_toolbar.png
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/latex_envs/doc/IEEEtran.bst
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/latex_envs/doc/biblio_ipython.bib
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/latex_envs/doc/latex_env_doc.ipynb
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/latex_envs/doc/header.tex
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/latex_envs/doc/README.md
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/latex_envs/doc/configuration_toolbar.png
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/latex_envs/doc/documentation.pdf
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/latex_envs/doc/latex_env_doc.html
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/latex_envs/doc/main_toolbar.png
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/latex_envs/doc/latex_env_doc.tex
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/latex_envs/doc/LaTeX_envs_menu.png
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/latex_envs/doc/example.png
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/latex_envs/doc/.ipynb_checkpoints/latex_env_doc-checkpoint.ipynb
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/latex_envs/doc/latex_env_doc_files/latex_env_doc_51_0.png
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/latex_envs/doc/latex_env_doc_files/latex_env_doc_42_0.png
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/latex_envs/doc/latex_env_doc_files/latex_env_doc_24_2.png
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/latex_envs/doc/latex_env_doc_files/latex_env_doc_44_0.png
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/latex_envs/doc/latex_env_doc_files/latex_env_doc_26_2.png
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/latex_envs/doc/latex_env_doc_files/latex_env_doc_41_0.png
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/latex_envs/doc/latex_env_doc_files/latex_env_doc_45_0.png
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/latex_envs/doc/latex_env_doc_files/latex_env_doc_27_2.png
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/latex_envs/doc/latex_env_doc_files/latex_env_doc_49_0.png
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/latex_envs/doc/latex_env_doc_files/latex_env_doc_43_0.png
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/latex_envs/doc/latex_env_doc_files/latex_env_doc_52_0.png
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/latex_envs/doc/latex_env_doc_files/latex_env_doc_50_0.png
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/latex_envs/doc/latex_env_doc_files/latex_env_doc_46_0.png
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/latex_envs/doc/latex_env_doc_files/latex_env_doc_23_2.png
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/latex_envs/doc/latex_env_doc_files/latex_env_doc_48_0.png
# [I 16:02:30 InstallContribNbextensionsApp] Up to date: /home/obga/.local/share/jupyter/nbextensions/latex_envs/doc/latex_env_doc_files/latex_env_doc_47_0.png
# [I 16:02:30 InstallContribNbextensionsApp] - Validating: OK
# [I 16:02:30 InstallContribNbextensionsApp] Installing jupyter_contrib_nbextensions items to config in /home/obga/.jupyter
# Enabling: jupyter_nbextensions_configurator
# - Writing config: /home/obga/.jupyter
#     - Validating...
#       jupyter_nbextensions_configurator 0.4.1 OK
# Enabling notebook nbextension nbextensions_configurator/config_menu/main...
# Enabling tree nbextension nbextensions_configurator/tree_tab/main...
# [I 16:02:30 InstallContribNbextensionsApp] Enabling notebook extension contrib_nbextensions_help_item/main...
# [I 16:02:30 InstallContribNbextensionsApp]       - Validating: OK
# [I 16:02:30 InstallContribNbextensionsApp] - Editing config: /home/obga/.jupyter/jupyter_nbconvert_config.json
# [I 16:02:30 InstallContribNbextensionsApp] --  Configuring nbconvert template path
# [I 16:02:30 InstallContribNbextensionsApp] --  Configuring nbconvert preprocessors
# [I 16:02:30 InstallContribNbextensionsApp] - Writing config: /home/obga/.jupyter/jupyter_nbconvert_config.json
# [I 16:02:30 InstallContribNbextensionsApp] --  Writing updated config file /home/obga/.jupyter/jupyter_nbconvert_config.json
# Enabling: jupyter_nbextensions_configurator
# - Writing config: /home/obga/.jupyter
#     - Validating...
#       jupyter_nbextensions_configurator 0.4.1 OK
# Enabling notebook nbextension nbextensions_configurator/config_menu/main...
# Enabling tree nbextension nbextensions_configurator/tree_tab/main...

# %% [markdown]
# # Metric spaces

# %% [markdown]
# #### Prove that:
# For every metric space (X, d):
# - For eny $\mathcal{U} = \{U | U$ is open in $(X, d)\}$ holds $\bigcup_{U \in \mathcal{U}} U$ is open in $(X, d)$
# - For eny two $U, V \subset X$ open in $(X, d)$ holds: $U \cap V$ is open in $(X, d)$
# - $X$ is open in $(X, d)$
# - $\emptyset$ is open in $(X, d)$
#
# - $a \subset x$
#
# proof:
#  $(x \in \bigcup_{U \in \mathcal{U}} U) \Rightarrow (\exists U_x \in \mathcal{U} : x \in U_x) \Rightarrow (B(x, r) \subset U_x) \Rightarrow (B(x, r) \subset \bigcup_{U \in \mathcal{U}} U)$
#
#  $x \in (U \cap V) \Rightarrow (x \in U \wedge x \in V) \Rightarrow (\exists r_1, r_2 : B(x, r_1) \subset U \wedge B(x, r_2) \subset V) \Rightarrow B(x, min(r_1, r_2)) \subset (U \cap V))$
#
#  $(\forall x \in X \forall r : B(x, r) \subset X) \Rightarrow (\forall x \in X \exists r : B(x, r) \subset X)$ (can pick any $r$, e.g. $r = 1$)
#
#  $\forall x \in \emptyset$ anything holds true, as there are no elements $x \in \emptyset$

# %% [markdown]
# #### Prove that:
# - For eny finity set $(U)_{i=1}^{n}$ of open sets in $(X, d)$, $\bigcap_{i=1}^{n}U$ is open in $(X, d)$
#
# By induction on $n$
#
# base case (n = 1):
#
# $\bigcap_{i=1}^1U_i = U_1$ and since $U_1$ is open, so is $\bigcap_{i=1}^1U_i$
#
# inductive step:
#
# $\bigcap_{i=1}^{n+1} U_i = (\bigcap_{i=1}^n U_i) \cap U_{n+1}$. First one is open by inductive hypothesis, $U_{n+1}$ is also obviously open. By second part of previous exercise the intersection of these must also be open. Q.E.D

# %% [markdown]
# #### Prove that for set $U \subset X$ is open if and only if for each point $x \in U$ there exists the open neighbourhood $V$ of $x$ such that $V \subset U$
#
# If $U$ is open $\forall x \exists B(x, r) \subset U$ and $B(x, r)$ is an open set s.t. $x \in B(x, r)$, so it can be taken to be $V$.
#
# If $\forall x \in U \exists V : (x \in V) \wedge (V \subset U) \wedge (V \text{ is open})$, then by definition $\exists B(x, r) \subset V$. $(B(x, r) \subset V) \wedge (V \subset U) \Rightarrow B(x, r) \subset U$, which means that $U$ is open.

# %% [markdown]
# #### Prove that, closed ball is closed subset in $(X, d)$
# $C(x_0, r) = \{ x \mid d(x, x_0) \leq r \}$
#
# $\overline{C(x_0, r)} = \{ x \mid d(x, x_0) > r \}$
#
# For each $x \in \overline{C(x_0, r)}$ take $d(x_0, x) - r = r'$ and $B(x, r') \subset \overline{C(x_0, r)}$. Thus $\overline{C(x_0, r)}$ is open and therefore $C(x_0, r)$ is closed.

# %% [markdown]
# #### Prove that
# For every metric space (X, d):
# - For eny $\mathcal{F} = \{F | F$ is closed in $(X, d)\}$ holds $\bigcap_{F \in \mathcal{F}} F$ is closed in $(X, d)$
# - For eny two $F_1, F_2 \subset X$ closed in $(X, d)$ holds: $F_1 \cup F_2$ is closed in $(X, d)$
# - $X$ is closed in $(X, d)$
# - $\emptyset$ is closed in $(X, d)$
#
# proof:
# - $\bigcap_{F \in \mathcal{F}} F = \overline{(\bigcup_{F \in \mathcal{F}} \overline{F})}$. Since each $\overline{F}$ is open, $\bigcup_{F \in \mathcal{F}} \overline{F}$ is open, so its complement is closed.
#
# - $F_1 \cup F_2 = \overline{\overline{F_1} \cap \overline{F_2}}$. $\overline{F_1}$ and $\overline{F_2}$ are open, so the union is also open. Thus, its complement is closed.
#
# - $\overline{X} = \emptyset$, which is open
#
# - $\overline{\emptyset} = X$, which is open

# %% [markdown]
# #### Prove that:
# - For eny finity set $(F)_{i=1}^{n}$ of closed sets in $(X, d)$, $\bigcup_{i=1}^{n}F$ is closed in $(X, d)$
#
# $\bigcup_{i = 1}^n F = \overline{\bigcap_{i = 1}^n \overline{F}}$. Since each $\overline{F}$ is open, so is $\bigcap_{i = 1}^n \overline{F}$, and thus its complement is closed.

# %% [markdown]
# #### Prove that, if $F \subset X$ is closed then $X - F$ is open in $(X, d)$
#
# $X - F$ is the complement of $F$. complement of a closed set is open, so $X - F$ is open.

# %% [markdown]
# # Metrics in Euclidean spaces

# %% [markdown]
# #### Prove that:
# - for every $u, v \in \mathbb{R}^{n}$: $d(u, v) \geq 0$
# - for every $v \in \mathbb{R}^{n}$: $d(v, v) = 0$
# - for every $u, v \in \mathbb{R}^{n}$: $d(u, v) = d(v, u)$ (symmetry)
# - for every $u, v, w \in \mathbb{R}^{n}$: $d(u, w) \leq d(v, u) + d(v, w)$ (triangle inequality)
#
# proof:
# 1) $d(u, v)$ is a root of sum of squares of real numbers, thus it is non-negative.
#
# 2) $d(v, v) = \sqrt{(v_1 - v_1)^2 + \dots + (v_n - v_n)^2} = \sqrt{0 + \dots + 0} = \sqrt{0} = 0$
#
# 3) $d(u, v) = d(v, u)$ since in every term $(v_i - u_i)^2 = (u_i - v_i)^2$
#
# 4) $d(u, w) = \sqrt{\sum_i (w_i - u_i)^2} = \sqrt{\sum_i (w_i - v_i + v_i - u_i)^2} = \sqrt{\sum_i (w_i - v_i)^2 + 2 \sum_i (w_i - v_i)(v_i - u_i) + \sum_i (v_i - u_i)^2} \overset{\text{by Cauchy-Schwarz}}\le \sqrt{d(w, v)^2 + 2 d(w, v) d(v, u) + d(v, u)^2} = \sqrt{(d(w, v) + d(v, u))^2} = d(w, v) + d(v, u)$

# %% [markdown]
# #### Prove the same properties hold for $d(u, v) = ||u-v||_1$ ($||u-v||_1 = \sum_{i = 1}^{n}|u_i - v_i|$)
# - Sum of absolute values cannot be negative
#
# - $d(v, v) = \sum_i | v_i - v_i | = \sum_i 0 = 0$
#
# - $d(u, v) = d(v, u)$ since $\forall i : | u_i - v_i | = | v_i - u_i |$
#
# - $d(u, w) = \sum_i | w_i - u_i | = \sum_i | w_i - v_i + v_i - u_i | \le \sum_i | w_i - v_i | + \sum_i | v_i - u_i | = d(w, v) + d(v, u)$

# %% [markdown]
# ## Sequences and limits

# %% [markdown]
# #### Prove that $x = \lim_{n\to\infty}{x_n}$ in $(X, d)$ if and only if (iff) for every $r \in \mathbb{R}$ there exists $n_0 \in \mathbb{N}$ such that: $x_i \in B(x, r)$ for every $i \gt n_0$

# %% [markdown]
# #### Prove that if $x = \lim_{n\to\infty}{x_n}$ and $x \notin \{-\infty, \infty\}$ then $(x_i)_{i=1}^{\infty} = (x_1, x_2, \dots, x_n)$ is a Cauchy sequence
# <br>
# For closed set $F \subset \mathbb{R}^n$ and convergent sequence $(x_i)_{i=1}^{\infty} = (x_1, x_2, \dots, x_n)$ such that there exists $n_0 \in \mathbb{N}$ such that $x_i \in F$ for each $i \gt n_0$ then: $\lim_{n\to\infty}{x_n} \in F$

# %% [markdown]
# #### Prove that if $F$ is open from previous example, statement does not hold.

# %% [markdown]
# #### Prove that inherited metric is a metric
#
# proof:
# ∀x,y∈H:dH(x,y)=d(x,y)
# As d is a metric, the metric space axioms are all fulfilled by all x,y∈A under d.
#
# As H⊆A, by definition of subset, all x,y∈H are also elements of A.
#
# Therefore the metric space axioms are all fulfilled by all x,y∈H under dH.

# %% [markdown]
# ## Limits of functions

# %% [markdown]
# Let $f:S \to Y$ is function between subset $S \subset X$ of a metric space $(X, d_x)$ and metric space $(Y, d_Y)$
# - We say that the limit of function $f:(S, d_x) \to (Y, d_Y)$ between metric spaces in some limit point $c \in X$ of the subset $S$ is $y \in Y $if for each open neighborhood of $y \in V \subset Y$ there exists the open seighborhood of $c \in U \subset X$ such that $f(U \cap S) \subset V$
# <br>
# This definition is equiualent of definition:
# <br>
# - The limit of function $f:(S, d_X) \to (Y, d_Y)$ between metric spaces in limit point $c \in X$ of the subset $S$ is $y \in Y $ if for each open ball $B(x, r) \subset Y$ there exists the ball $B(c, l) \subset X$ such that $f(B(c, l) \cap S) \subset B(y, r)$
# <br>
# or
# <br>
# - The limit of function $f:(S, d_X) \to (Y, d_Y)$ between metric spaces in limit point $c \in X$ of subset $S$ is $y \in Y $ if for any $r \in \mathbb{R}$ there exists $l \in \mathbb{R}$ such that for every $x \in S$ with $d_X(x, c) < l$ implies that $d_Y(f(x), y) < r$

# %% [markdown]
# #### Prove that this three definitions are equiualent for eny function between eny two metric spaces

# %% [markdown]
# ## Continuous functions

# %% [markdown]
# #### Prove that function is continuous in $c$ if for eny sequence $(x_n)_{n=1}^{\infty} \subset X$ such that $\lim_{n \to \infty}x_n = c$ we have $\lim_{n \to \infty}f(x_n) = f(c)$

# %% [markdown]
# #### Prove that function is continuous if for every open set $V \subset Y$ the $f^{-1}(V)$ is open in $X$
#
# If $f^{-1}(V)$ is open $\forall c \in f^{-1}(V) \exists B(c, r) : B(c, r) \subset f^{-1}(V) \Rightarrow f(B(c, r)) \subset V$ and $B(c, r) is open.

# %% [markdown]
# #### Prove that function is continuous if for every closed set $F \subset Y$ the $f^{-1}(F)$ is open in $X$
#
# $f^{-1}(\overline{F}) = \overline{f^{-1}(F)}$, Thus if this holds, then the previous statement also holds.

# %% [markdown]
# #### Prove that any composition of continous functions is continous
#
# proof:
# Let ϵ > 0 be given.let g be continuous at f(c), there exists η > 0 such
# that
# |y − f(c)| < η and y ∈ B implies that |g(y) − g (f(c))| < ϵ.
# Next, since f is continuous at c, there exists δ > 0 such that
# |x − c| < δ and x ∈ A implies that |f(x) − f(c)| < η.
# Combing these inequalities, we get that
# |x − c| < δ and x ∈ A implies that |g (f(x)) − g (f(c))| < ϵ,
# which proves that g ◦ f is continuous at c.
